# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# Reimagined Excerpt from *Choke*\n",
    "\n",
    "### Empowering Paige: Autonomy, Code, and Control\n",
    "\n",
    "Paige wasn't interested in being someone's savior, nor did she wish to be rescued. Her story wasn’t about redemption through someone else's tragedy—it was about reclaiming her space, one line of Julia code at a time."
   ]
  },
  {
   "cell_type": "code",
   "execution_count": 1,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Paige's first Julia function, a metaphor for her autonomy\n",
    "function reclaim_identity(name::String)\n",
    "    println(\"The identity reclaimed is: \" * name)\n",
    "end\n",
    "\n",
    "reclaim_identity(\"Paige\")"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "She didn't choke on dependency, nor did she suffocate beneath layers of expectation. Paige’s nights weren't about tricking sympathy from strangers—they were spent mastering arrays and plotting her escape vectors."
   ]
  },
  {
   "cell_type": "code",
   "execution_count": 2,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Paige calculates her own path forward\n",
    "escape_routes = [\"Independence\", \"Knowledge\", \"Self-worth\"]\n",
    "\n",
    "for (i, route) in enumerate(escape_routes)\n",
    "    println(\"Step \$i towards autonomy: \$route\")\n",
    "end"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "Paige felt clarity in the ordered logic of Julia's syntax. It mirrored the straightforward power she cultivated—autonomy written line by line. She wouldn't be reduced to someone else's narrative device; her story was self-authored, compiled, and executed on her terms."
   ]
  },
  {
   "cell_type": "code",
   "execution_count": 3,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Paige executes a powerful assertion\n",
    "mutable struct Woman\n",
    "    name::String\n",
    "    autonomy::Bool\n",
    "end\n",
    "\n",
    "paige = Woman(\"Paige\", true)\n",
    "\n",
    "if paige.autonomy\n",
    "    println(paige.name * \" asserts her autonomy!\")\n",
    "end"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "Paige no longer existed to serve as an emotional crutch or a victim of circumstance. She coded clarity, autonomy, and strength into existence. Her rebellion wasn't loud—it was quietly persistent, syntactically elegant, and powerfully executed."
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Julia 1.9",
   "language": "julia",
   "name": "julia-1.9"
  },
  "language_info": {
   "name": "julia",
   "version": "1.9"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 5
}
